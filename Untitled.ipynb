# %%
import urllib3.request
import pandas as pd
from urllib.request import Request, urlopen
from fake_useragent import UserAgent
import io

# %%
class AppURLopener(urllib.request.FancyURLopener):
        version = "Mozilla/5.0"
opener = AppURLopener()
response = opener.open('https://www2.census.gov/geo/docs/maps-data/data/rel/zcta_county_rel_10.txt')
# Out:
# /Users/shannonskinner/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DeprecationWarning: AppURLopener style of invoking requests is deprecated. Use newer urlopen functions/methods
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
response
# Out:
# <addinfourl at 4685492520 whose fp = <http.client.HTTPResponse object at 0x116b0ddd8>>

# %%
zips = pd.read_csv(response, dtype={'ZCTA5': str, 'STATE': str, 'COUNTY':str, 'GEOID':str})

# %%
zipcode = '11211'

# %%
input_zip=zipcode
header = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.3'}
ua=UserAgent()
    
zip_req = Request('https://www2.census.gov/geo/docs/maps-data/data/rel/zcta_county_rel_10.txt')    
zip_req.add_header('User-Agent', ua.chrome)
zip_req2 = urlopen(zip_req)
zips = pd.read_csv(zip_req2,  dtype={'ZCTA5': str, 'STATE': str, 'COUNTY':str, 'GEOID':str}) #read census data for zipcodes & state / county

# %%
from urllib.request import urlopen, Request
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.3'}
reg_url = "https://www2.census.gov/geo/docs/maps-data/data/rel/zcta_county_rel_10.txt"

# %%
req = Request(url=reg_url, headers=headers) 
html = urlopen(req).read()

# %%
c=pd.read_csv(io.StringIO(s.decode('utf-8')))

# %%
zips = pd.read_csv(io.StringIO(html.decode('utf-8')),  dtype={'ZCTA5': str, 'STATE': str, 'COUNTY':str, 'GEOID':str}) #read census data for zipcodes & state / county

# %%
place_url = 'https://www2.census.gov/geo/docs/maps-data/data/rel/zcta_place_rel_10.txt'
place_req = Request(url=place_url, headers=header)
place_html = urlopen(place_req).read()
place_zip = pd.read_csv(io.StringIO(place_html.decode('utf-8')), dtype={'ZCTA5': str, 'STATE': str, 'PLACE':str, 'GEOID':str})
places = pd.read_csv('https://www2.census.gov/geo/docs/reference/codes/files/national_places.txt', 
                     encoding='latin-1', sep='|', 
                     header=0, names=['STATE','STATEFP', 'PLACEFP', 'PLACENAME', 'TYPE', 'FUNCSTAT', 'COUNTY'], 
                     dtype={'STATEFP': str, 'PLACEFP':str})#import places list

# %%
pd.places['PLACENAME'].values[1].rsplit(' ', 1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-61-23b9dbbef518> in <module>()
# ----> 1 pd.places['PLACENAME'].values[1].rsplit(' ', 1)
#
# AttributeError: module 'pandas' has no attribute 'places'

# %%
places_new = places

# %%
places['PLACE_NAME'] = places['PLACENAME'].str.rsplit(' ', n=1, expand=True)[0]
places['PLACE_TYPE'] = places['PLACENAME'].str.rsplit(' ', n=1, expand=True)[1]

# %%
places_new
# Out:
#       STATE STATEFP PLACEFP                          PLACENAME  \
# 0        AL      01   00100                         Abanda CDP
# 1        AL      01   00124                     Abbeville city
# 2        AL      01   00460                    Adamsville city
# 3        AL      01   00484                       Addison town
# 4        AL      01   00676                         Akron town
# 5        AL      01   00820                     Alabaster city
# 6        AL      01   00988                   Albertville city
# 7        AL      01   01132                Alexander City city
# 8        AL      01   01180                     Alexandria CDP
# 9        AL      01   01228                    Aliceville city
# 10       AL      01   01396                       Allgood town
# 11       AL      01   01660                       Altoona town
# 12       AL      01   01708                     Andalusia city
# 13       AL      01   01756                      Anderson town
# ...

# %%
data["Team"]= data["Team"].str.split("t", n = 1, expand = True)
# Out:
# ['Abbeville', 'city']

# %%
x.rsplit(' ', 1)
# Out:
# ['Abbeville', 'city']

# %%
places['PLACENAME'].values[1]
# Out:
# 'Abbeville city'
